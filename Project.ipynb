# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.0'

# %%
# Read all excel file
xls = pd.ExcelFile('School-Age-Digital-Connectivity.xlsx')

# %% [markdown]
# testing

# %%
df1 = pd.read_excel('School-Age-Digital-Connectivity.xlsx','Total school age', header=[1])
df1.head()
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 UNICEF Sub-region 1  \
# 0        DZA     Algeria       MENA                MENA
# 1        AGO      Angola        SSA                 ESA
# 2        ARG   Argentina        LAC                 LAC
# 3        ARM     Armenia        ECA                EECA
# 4        BGD  Bangladesh         SA                  SA
#
#                  Unnamed: 4  Unnamed: 5     Rural     Urban   Poorest  \
# 0  Upper middle income (UM)    0.237807  0.091202  0.322005  0.005888
# 1  Lower middle income (LM)    0.165507  0.017646  0.243431  0.000000
# 2  Upper middle income (UM)    0.398849       NaN       NaN       NaN
# 3  Upper middle income (UM)    0.809218  0.709329  0.883609  0.466020
# 4  Lower middle income (LM)    0.366474  0.327793  0.516416  0.087617
#
#     Richest                        Data source Time period
# 0  0.772502  Multiple Indicator Cluster Survey     2018-19
# 1  0.624589      Demographic and Health Survey     2015-16
# ...

# %%
df = pd.read_excel(xls, 'Total school age', header=[1])  # remove Wealth quantile and Residence to make it a single column header to easily access the data by their column name
df.rename(columns={"Unnamed: 0": "ISO3"}, inplace=True)
df.rename(columns={"Unnamed: 1": "Countries and areas"}, inplace=True)
df.rename(columns={"Unnamed: 2": "Region"}, inplace=True)
df.rename(columns={"UNICEF Sub-region 1": "Sub-region"}, inplace=True)
df.rename(columns={"Unnamed: 4": "Income Group"}, inplace=True)
df.rename(columns={"Unnamed: 5": "Total"}, inplace=True)
df.head()
# Out:
#   ISO3 Countries and areas Region Sub-region              Income Group  \
# 0  DZA             Algeria   MENA       MENA  Upper middle income (UM)
# 1  AGO              Angola    SSA        ESA  Lower middle income (LM)
# 2  ARG           Argentina    LAC        LAC  Upper middle income (UM)
# 3  ARM             Armenia    ECA       EECA  Upper middle income (UM)
# 4  BGD          Bangladesh     SA         SA  Lower middle income (LM)
#
#       Total     Rural     Urban   Poorest   Richest  \
# 0  0.237807  0.091202  0.322005  0.005888  0.772502
# 1  0.165507  0.017646  0.243431  0.000000  0.624589
# 2  0.398849       NaN       NaN       NaN       NaN
# 3  0.809218  0.709329  0.883609  0.466020  0.991219
# 4  0.366474  0.327793  0.516416  0.087617  0.758899
#
#                          Data source Time period
# 0  Multiple Indicator Cluster Survey     2018-19
# 1      Demographic and Health Survey     2015-16
# 2  Multiple Indicator Cluster Survey     2011-12
# ...

# %%
df = df.dropna() # drop null values cause it will bother the total percentage and it represents incompleteness

# %%
df.drop_duplicates() # no duplicates
# Out:
#    ISO3 Countries and areas Region Sub-region              Income Group  \
# 0   DZA             Algeria   MENA       MENA  Upper middle income (UM)
# 1   AGO              Angola    SSA        ESA  Lower middle income (LM)
# 3   ARM             Armenia    ECA       EECA  Upper middle income (UM)
# 4   BGD          Bangladesh     SA         SA  Lower middle income (LM)
# 5   BRB            Barbados    LAC        LAC           High income (H)
# ..  ...                 ...    ...        ...                       ...
# 78  TKM        Turkmenistan    ECA       EECA  Upper middle income (UM)
# 79  UGA              Uganda    SSA        ESA            Low income (L)
# 83  UZB          Uzbekistan    ECA       EECA  Lower middle income (LM)
# 85  ZMB              Zambia    SSA        ESA  Lower middle income (LM)
# 86  ZWE            Zimbabwe    SSA        ESA  Lower middle income (LM)
#
#        Total     Rural     Urban   Poorest   Richest  \
# ...

# %%
df[df["Rural"]>0.5]
# Out:
#    ISO3     Countries and areas Region Sub-region              Income Group  \
# 3   ARM                 Armenia    ECA       EECA  Upper middle income (UM)
# 5   BRB                Barbados    LAC        LAC           High income (H)
# 8   BIH  Bosnia and Herzegovina    ECA       EECA  Upper middle income (UM)
# 9   BRA                  Brazil    LAC        LAC  Upper middle income (UM)
# 10  BGR                Bulgaria    ECA       EECA  Upper middle income (UM)
# 15  CHL                   Chile    LAC        LAC           High income (H)
# 18  CRI              Costa Rica    LAC        LAC  Upper middle income (UM)
# 27  GEO                 Georgia    ECA       EECA  Upper middle income (UM)
# 35  JPN                   Japan    EAP        EAP           High income (H)
# 39  KGZ              Kyrgyzstan    ECA       EECA  Lower middle income (LM)
# 43  MDV                Maldives     SA         SA  Upper middle income (UM)
# ...

# %%
df.groupby(['Region']).mean()
# Out:
#            Total     Rural     Urban   Poorest   Richest
# Region
# EAP     0.497968  0.424291  0.567481  0.307331  0.726421
# ECA     0.659829  0.576441  0.738631  0.394817  0.895325
# LAC     0.437634  0.295307  0.511702  0.214515  0.801110
# MENA    0.372904  0.252756  0.431987  0.127440  0.790099
# SA      0.402059  0.349365  0.501465  0.243909  0.730596
# SSA     0.117556  0.065675  0.194499  0.024212  0.323383

# %%
df.groupby(['Income Group']).mean()
# Out:
#                              Total     Rural     Urban   Poorest   Richest
# Income Group
# High income (H)           0.609016  0.517570  0.661457  0.303771  0.947551
# Low income (L)            0.139940  0.085174  0.222810  0.030539  0.335427
# Lower middle income (LM)  0.209423  0.136822  0.299423  0.061532  0.500385
# Upper middle income (UM)  0.575366  0.474461  0.641966  0.363986  0.847056

# %%
df2 = pd.read_csv("fifa21 raw data v2.csv")
df2
# Out:
# C:\Users\kerojol\AppData\Local\Temp\ipykernel_12304\379165875.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("fifa21 raw data v2.csv")
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# ...

# %%
new_df2 = df2[['Club', 'Age']]
new_df2 = new_df2.replace('\n','', regex=True)
new_df2.groupby(['Club']).mean().sort_values(by='Age')
# Out:
#                                      Age
# Club
# Bayern München II              20.571429
# FC Nordsjælland                20.846154
# SC Heerenveen                  21.208333
# Famalicão                      21.433333
# Barnsley                       21.533333
# ...                                  ...
# AC Mineros de Guayana          29.040000
# Shanghai Greenland Shenhua FC  29.115385
# Al Fayha                       29.200000
# No Club                        29.316456
# Qingdao Huanghai F.C.          29.360000
#
# [682 rows x 1 columns]

# %%
df2 = df2.replace('\n','', regex=True)
df2 = df2[df2["Club"]=="Tottenham Hotspur"]
df2[["Club","Height","Heading Accuracy"]]
# Out:
#                     Club Height  Heading Accuracy
# 23     Tottenham Hotspur  188cm                85
# 36     Tottenham Hotspur  183cm                68
# 46     Tottenham Hotspur  188cm                10
# 82     Tottenham Hotspur  186cm                82
# 151    Tottenham Hotspur  178cm                60
# 162    Tottenham Hotspur  174cm                62
# 166    Tottenham Hotspur  188cm                81
# 205    Tottenham Hotspur  185cm                84
# 219    Tottenham Hotspur  177cm                57
# 228    Tottenham Hotspur  178cm                75
# 308    Tottenham Hotspur  187cm                80
# 337    Tottenham Hotspur  182cm                74
# 381    Tottenham Hotspur  181cm                56
# 382    Tottenham Hotspur  182cm                66
# 421    Tottenham Hotspur  185cm                63
# 469    Tottenham Hotspur  174cm                75
# 496    Tottenham Hotspur  184cm                67
# 512    Tottenham Hotspur  190cm                70
# ...

# %% [markdown]
# ## Inferential Question
#
# ### `Hypothesis:` A high income group is linked with a higher percentage of children that have higher internet connection at home based on Japan's data.
# #### `Question:` Is the hypothesis is also true for Chile? (Chile is also linked with high income group)

# %% [markdown]
# Testing the hypothesis

# %%
df
# Out:
#    ISO3 Countries and areas Region Sub-region              Income Group  \
# 0   DZA             Algeria   MENA       MENA  Upper middle income (UM)
# 1   AGO              Angola    SSA        ESA  Lower middle income (LM)
# 3   ARM             Armenia    ECA       EECA  Upper middle income (UM)
# 4   BGD          Bangladesh     SA         SA  Lower middle income (LM)
# 5   BRB            Barbados    LAC        LAC           High income (H)
# ..  ...                 ...    ...        ...                       ...
# 78  TKM        Turkmenistan    ECA       EECA  Upper middle income (UM)
# 79  UGA              Uganda    SSA        ESA            Low income (L)
# 83  UZB          Uzbekistan    ECA       EECA  Lower middle income (LM)
# 85  ZMB              Zambia    SSA        ESA  Lower middle income (LM)
# 86  ZWE            Zimbabwe    SSA        ESA  Lower middle income (LM)
#
#        Total     Rural     Urban   Poorest   Richest  \
# ...
